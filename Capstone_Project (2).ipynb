# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random as rd

# %%
def main():
    df = pd.read_csv('Chevy_US_Data.csv')
    
    
    
    TARGET_COL = "Total Sales"
    POSSIBLE_EXCLUDES = ["pid", TARGET_COL]
    
    indices = list(range(0, 20))
    
    starting_index = rd.randint(0, 19)
    
    
    
    #print(starting_index)
    
    i = starting_index
    
    
    train = []
    validate = []
    test = []
    
    for j in range(len(indices)//3):
        if(i >= 19):
            i %= 20
        #print("Train i: ", i)
        train.append(indices[i])
    
        if(i + 3 <= len(indices)-1):
            i += 3
    
        else:
            i += 3
            i %= 20
    
    
    
    
    i = starting_index + 1
    
    for j in range(len(indices)//3):
        if(i >= 19):
            i %= 20
        #print("Validate i: ", i)
        validate.append(indices[i])
    
        if(i + 3 <= len(indices)-1):
            i += 3
    
        else:
            i += 3
            i %= 20
    
    
    i = starting_index + 2
    
    for j in range(len(indices)//3):
        if(i >= 19):
            i %= 20
        #print("Test i: ", i)
        test.append(indices[i])
    
        if(i + 3 <= len(indices)-1):
            i += 3
    
        else:
            i += 3
            i %= 20
    
    
    print(train)
    print(validate)
    print(test)
    
    
    
    train_df = df.iloc[train].copy()
    val_df = df.iloc[validate].copy()
    test_df = df.iloc[test].copy()
    
    
    y_train = train_df[TARGET_COL].to_numpy(dtype=float)
    y_val = val_df[TARGET_COL].to_numpy(dtype=float)
    y_test = test_df[TARGET_COL].to_numpy(dtype=float)
    
    
    
    
    X_train = train_df.drop(columns=[c for c in POSSIBLE_EXCLUDES if c in train_df.columns])
    X_val = val_df.drop(columns=[c for c in POSSIBLE_EXCLUDES if c in val_df.columns])
    X_test = test_df.drop(columns=[c for c in POSSIBLE_EXCLUDES if c in test_df.columns])
    
    
    
    
    # This is going ot be disregarded. The reason is that everything in the data set is a numeric column, and there are no categorical columns to work with
    numeric_cols = [c for c in X_train.columns if pd.api.types.is_numeric_dtype(X_train[c])]
    
    
    print(numeric_cols)

    
    
    
    
    
    
    # Impute missing values (if any exist)
    
    
    X_trains_medians = {}
    
    
    
    for c in numeric_cols:
        X_trains_medians[c] = X_train[c].median()
    
    
    
    X_train.fillna(value=X_trains_medians)
    X_val.fillna(value=X_trains_medians)
    X_test.fillna(value=X_trains_medians)
    
    
    
    
    X_trains_means = {}
    X_trains_stds = {}
    
    
    for c in numeric_cols:
        X_trains_means[c] = X_train[c].mean()
        X_trains_stds[c] = X_train[c].std()
    
    
    
    
    Z_X_Train = pd.DataFrame(columns=X_train.columns)
    Z_X_Val = pd.DataFrame(columns=X_val.columns)
    Z_X_Test = pd.DataFrame(columns=X_test.columns)
    
    
    
    
    for c in numeric_cols:
        Z_X_Train[c] = (X_train[c] - X_trains_means[c]) / X_trains_stds[c]
        Z_X_Val[c] = (X_val[c] - X_trains_means[c]) / X_trains_stds[c]
        Z_X_Test[c] = (X_test[c] - X_trains_means[c]) / X_trains_stds[c]
    






i = 0



while(i <= 100):
    main()
    i += 1
# Out:
# [15, 18, 1, 4, 7, 10]
# [16, 19, 2, 5, 8, 11]
# [17, 0, 3, 6, 9, 12]
# ['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'YOY Change', 'US Marketshare', 'Marketshare change']
# [19, 2, 5, 8, 11, 14]
# [0, 3, 6, 9, 12, 15]
# [1, 4, 7, 10, 13, 16]
# ['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'YOY Change', 'US Marketshare', 'Marketshare change']
# [5, 8, 11, 14, 17, 0]
# [6, 9, 12, 15, 18, 1]
# [7, 10, 13, 16, 19, 2]
# ['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'YOY Change', 'US Marketshare', 'Marketshare change']
# [1, 4, 7, 10, 13, 16]
# [2, 5, 8, 11, 14, 17]
# [3, 6, 9, 12, 15, 18]
# ['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'YOY Change', 'US Marketshare', 'Marketshare change']
# [8, 11, 14, 17, 0, 3]
# [9, 12, 15, 18, 1, 4]
# [10, 13, 16, 19, 2, 5]
# ...
